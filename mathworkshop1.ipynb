# %% [markdown]
# <a href="https://colab.research.google.com/github/RIPBloxy/SEM2_Computational_Math_workshops/blob/main/mathworkshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Rajib Shrestha
#
# Uni ID: 2614040

# %%
length = 10
width = 5
area = length * width
print(area)
# Out:
# 50

# %% [markdown]
# Implicit conversion

# %%
print(7+8.5)
# Out:
# 15.5

# %% [markdown]
# Explicit conversion

# %%
base = 6
height = 2
area = base*height/2
print("Area is " + str(area))
# Out:
# Area is 6.0

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour using input( ) to compute
# gross pay. Pay the hourly rate for the hours up to 40 and 1.5 times the hourly rate for all
# hours worked above 40 hours. Use 45 hours and a rate of 10.50 per hour to test the program
# (the pay should be 498.75).
#
# hrs = input("Enter Hours:")
#
# h = float(hrs)
#
# rate = input("Enter the rate per hour:")
#
# r = float(rate)

# %%
hrs = input("Enter Hours:")
h = float(hrs)
rate = input ("Enter the rate per hour:")
r = float(rate)
if(h<=40):
  pay=h*r
else:
  pay=40*r+((h-r)*r*1.5)
print(pay)
# Out:
# Enter Hours:45
# Enter the rate per hour:10.50
# 963.375

# %% [markdown]
# function

# %%
def greeting (name):
  print("Welcome "+ name)
greeting("Rajib shrestha")
# Out:
# Welcome Rajib shrestha

# %%
def area_traingle(b, h):
  return b*h/2
  area = area_traingle(4, 8)
print("area of traingle is: " + str(area))
# Out:
# area of traingle is: 6.0

# %%
def order_numbers(number1, number2):
  if number2 > number1:
    return number2,number1
  else:
    return number1, number2
smaller, bigger = order_numbers(100, 99)
print(smaller, bigger)
# Out:
# 100 99

# %% [markdown]
# conditional

# %%
def is_Even(number):
  if (number%2 == 0):
    return True
  return False
is_Even(8)
# Out:
# True

# %%
def number_group(number):
  if number > 0:
    return "Positive"
  elif number == 0:
    return "Zero"
  else:
    return "Negative"
print(number_group(10)) #Should be Positive
print(number_group(0)) #Should be Zero
print(number_group(-5)) #Should be Negative
# Out:
# Positive
# Zero
# Negative
