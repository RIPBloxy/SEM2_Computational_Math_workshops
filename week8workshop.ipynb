# %% [markdown]
# <a href="https://colab.research.google.com/github/RIPBloxy/SEM2_Computational_Math_workshops/blob/main/week8workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rajib shrestha
#
# uni id: 2614040

# %% [markdown]
# example 1

# %%
import numpy as np

import matplotlib.pyplot as plt

""" Part 1 - Problem 1: Solve linear systems graphically. """

# Generate 100 equidistant point between -5 to 5 for x

x = np.linspace(-5,5,100)

## Calculate y values for Equation 1 and 2

y1 = (5-x)/3

y2 = (5+x)/2

y3 = 3-x

## Generate a figure frame for plotting the lines

fig, ax = plt.subplots()

## Plot the two lines

ax.plot(x,y1, color='r')

ax.plot(x,y2, color='g')

ax.plot(x,y3, color='b')

## To decorate the plot, we insert equations.

ax.text(0.5,0.6, '$x+3y = 5$', color='r')

ax.text(-3,0.5,'$x-2y = -5$', color='g')

ax.text(1.2,2, '$x+y = 3$', color='b')

## Set the limits of the X & Y axes.

ax.set_xlim(-4,4)

ax.set_ylim(-2,6)

## Set property of X and Y axes, e.g., color and linewidth

ax.axvline(color='k',linewidth = 1)

ax.axhline(color='k',linewidth = 1)

## This option specifies the ticks based the list of numbers provided.

ax.set_xticks(list(range(-4,5)))

ax.set_aspect('equal')

ax.grid(True,ls=':')

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %%
#Task 1
import numpy as np
import matplotlib.pyplot as plt

""" Part 1 - Problem 1: Solve linear systems graphically. """

# Generate 100 equidistant point between -5 to 5 for x

x = np.linspace(-5,5,100)

## Calculate y values for Equation 1 and 2

y1 = (3-2*x)/3

y2 = (6-4*x)/6

y3 = (1+3*x)/2

## Generate a figure frame for plotting the lines

fig, ax = plt.subplots()

## Plot the two lines

ax.plot(x,y1, color='r')

ax.plot(x,y2, color='g')

ax.plot(x,y3, color='b')

## To decorate the plot, we insert equations.

ax.text(0.5,0.6, '$2x+3y = 3$', color='r')

ax.text(-3,0.5,'$4x+6y = 6$', color='g')

ax.text(1.2,2, '$3x-2y = 1$', color='b')

## Set the limits of the X & Y axes.

ax.set_xlim(-4,4)

ax.set_ylim(-2,6)

## Set property of X and Y axes, e.g., color and linewidth

ax.axvline(color='k',linewidth = 1)

ax.axhline(color='k',linewidth = 1)

## This option specifies the ticks based the list of numbers provided.

ax.set_xticks(list(range(-4,5)))

ax.set_aspect('equal')

ax.grid(True,ls=':')

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %% [markdown]
# Task 2:
#
# 1:
# Create a program that reads in two 5x6 numpy.arrays, adds them together, and then stores the result in a third 5x6 matrix. The program should then print out the first two matrices and the result matrix.

# %%
import numpy as np
A = np.random.randint(1,11,(5,6))
B = np.random.randint(1,11,(5,6))
C = A + B ;
print(A)
print(B)
print(C)
# Out:
# [[ 1  8  4  2  9  4]
#  [ 8 10  8  1  1 10]
#  [ 5  5  9  8 10  5]
#  [ 3  3  4  2  6  5]
#  [ 3  7  8  7  6  1]]
# [[ 2  5  7  5  5  3]
#  [ 8  1  7 10  2  3]
#  [ 7  5 10  3  8  7]
#  [ 4  6  8  2  9  7]
#  [10  6  5  9  3  4]]
# [[ 3 13 11  7 14  7]
#  [16 11 15 11  3 13]
#  [12 10 19 11 18 12]
#  [ 7  9 12  4 15 12]
#  [13 13 13 16  9  5]]

# %% [markdown]
# 2. Create a program that reads in three 2x3 numpy.arrays, subtracts the second from the first, and adds the third to the result. The program should then print out all three matrices and the result matrix.

# %%
import numpy as np
A = np.random.randint(1,11,(2,3))
B = np.random.randint(1,11,(2,3))
C = np.random.randint(1,11,(2,3))
D = (B - A)+ C ;
print(A)
print(B)
print(C)
print(D)
# Out:
# [[ 8  8  1]
#  [ 5 10 10]]
# [[3 4 5]
#  [9 6 6]]
# [[ 1 10  3]
#  [ 8 10  2]]
# [[-4  6  7]
#  [12  6 -2]]

# %% [markdown]
# 3. Create a 4x4 matrix containing random numbers in the range of 1 to 20. Have the user prompted for a number, check that the imputed value is a number and then check if the number is in the matrix. If the number is in the matrix, return the number of times that number is in the matrix.

# %%
import numpy as np
A = np.random.randint(1,20,(4,4))
B = int(input("enter the number"))
print(A)
if B in A:
  print("the number is in the matrix")
  print(np.count_nonzero(A == B))
else:
  print("the number is not in the matrix")
# Out:
# enter the number2
# [[17  6  3 11]
#  [16 11 10  8]
#  [ 3 14 14  3]
#  [ 2  8 11  3]]
# the number is in the matrix
# 1

# %%
import numpy as np
a = np.array([[1, 2], [3, 4]])
det = np.linalg.det(a)
print("Determinant:", det)
# Out:
# Determinant: -2.0000000000000004

# %%
rank = np.linalg.matrix_rank(a)
print("Rank:", rank)
# Out:
# Rank: 2

# %%
inv = np.linalg.inv(a)
print("Inverse:\n", inv)
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
b = np.array([1, 2])
x = np.linalg.solve(a, b)
print("Solution:", x)
# Out:
# Solution: [0.  0.5]

# %%
import numpy as np
a = np.random.randn(3, 2)
b = np.linalg.pinv(a)
result = np.allclose(a, np.dot(a, np.dot(b, a)))
print("Check A A+ A = A:", result)
# Out:
# Check A A+ A = A: True

# %%
#Task 3 A
import numpy as np
A = np.random.randint(1, 20, (5, 5))
print("Matrix A:\n", A)
rank = np.linalg.matrix_rank(A)
print("Rank of A:", rank)
det = np.linalg.det(A)
print("Determinant of A:", det)
if rank == 5 and det != 0:
    print("Matrix is invertible")
else:
    print("Matrix is NOT invertible")
# Out:
# Matrix A:
#  [[18 16  6 18 17]
#  [19  3  7  2 12]
#  [11  9 13 11 10]
#  [ 6 18  6 17  9]
#  [13 12 11  6  8]]
# Rank of A: 5
# Determinant of A: -11802.000000000013
# Matrix is invertible

# %%
#Task 3 B
A = np.random.rand(5,5)
x = np.random.rand(5)
b = np.dot(A, x)
x_sol = np.linalg.solve(A, b)
print(x_sol)
# Out:
# [0.53243334 0.57713309 0.2427045  0.44625649 0.57072631]

# %%
#Task 3 C
import numpy as np
A = np.array([
    [8, 3, -2],
    [-4, 7, 5],
    [3, 4, -12]
])
b = np.array([9, 15, 35])
x = np.linalg.solve(A, b)
print("Solution:", x)
# Out:
# Solution: [-0.58226371  3.22870478 -1.98599767]

# %%
#Task 4
import numpy as np
import matplotlib.pyplot as plt
x = np.array([3,2,1,0,1,2,3,4,5,7])
y = np.array([7.6,1,4.8,5,2.8,0.6,4,6.2,6,6.4])
coeffs = np.polyfit(x, y, 2)
poly = np.poly1d(coeffs)
x_line = np.linspace(min(x), max(x), 100)
y_line = poly(x_line)
plt.scatter(x, y)
plt.plot(x_line, y_line)
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
print("Polynomial:", poly)
# Out:
# Polynomial:          2
# 0.06667 x + 0.06667 x + 3.467
