# %% [markdown]
# <a href="https://colab.research.google.com/github/RIPBloxy/SEM2_Computational_Math_workshops/blob/main/worshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Rajib Shrestha
#
# Student id: 2614040

# %%
from math import pi, sin
def deg_sin():
  x = float(input("Please input a number "))
  answer = sin(pi*x/180)
  print("result = {}".format(answer))
deg_sin()
# Out:
# Please input a number 234
# result = -0.8090169943749473
